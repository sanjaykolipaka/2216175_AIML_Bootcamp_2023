# %%
#AI_ML Bootcamp
# ASSIGNMENT-1

# %%
#1.Implement the methods of strings with examples.

#strings

str="Iam a member of Gradstellar"

print(str[0])

print(str[-8])

#slicing

print(str[0:13])

#from:to(n-1):3

print(str[0:5:3])

#reverse of string

print(str[::-1])

#string methods

string="i am learning python programming language"

print(string.upper())

print(string.lower())

print(string.swapcase())

print(string.lstrip())

#string operations

str1="Artificial"

str2="Intelligence"

print(str1+str2)

print(str2*2)

print(str1+str1)

#Comparing string

str1 = "i am learning machine learning"

str2 = "I am learning Python"

print(str1==str2)
# Out:
# I
# d
# Iam a member
# I
# ralletsdarG fo rebmem a maI
# I AM LEARNING PYTHON PROGRAMMING LANGUAGE
# i am learning python programming language
# I AM LEARNING PYTHON PROGRAMMING LANGUAGE
# i am learning python programming language
# ArtificialIntelligence
# IntelligenceIntelligence
# ArtificialArtificial
# False

# %%
#2.Implement the methods of list with examples

#lists
list1=[10,20,30,40]
list2=[45,"python","15.8"]
list3=["AI","ML","Bootcamp"]

#indexing
print(list1[2])
print(list1[-4])

#slicing
print(list1[:3])

#nested list
list4=["coding",list1,list2]
print(list4[0][0:6])
print(list4[2][1:2][0][0])

#list method
list1.append(76)
print(list1)

l1=[9,5,3,75,24,29,38,34]

print(l1.count(4))
print(len(l1))
print(l1[::-1])
l1.sort()
print(l1)
# Out:
# 30
# 10
# [10, 20, 30]
# coding
# p
# [10, 20, 30, 40, 76]
# 0
# 8
# [34, 38, 29, 24, 75, 3, 5, 9]
# [3, 5, 9, 24, 29, 34, 38, 75]

# %%
#3.Implement methods of tuples with examples.

#Tuples
tup1=(10,20,30,40)
tup2=("stellar",5.9,5)
tup3=("python",tup1,tup2)
print(tup3[-1][-1])

#tuple methods
print(tup1.count(1))
print(tup1.index(20))
print(max(tup1))
print(min(tup1))
print(tup1[3:8])
print(tup1[:-1])
print(tup1[3:])
print(tup1[:])
# Out:
# 5
# 0
# 1
# 40
# 10
# (40,)
# (10, 20, 30)
# (40,)
# (10, 20, 30, 40)

# %%
#4.Implement the methods of dictionary with examples.
#dictionaries
dict1={'name':'stellar',175:'aiml'}
print(dict1['name'])
print(dict1.keys())
print(dict1.values())
print(dict1.get("name"))

Items_list = {1: "mangoes", 2: "Apples", 3: "Bananas"}
print(Items_list)
del Items_list[1]
print(Items_list)
# Out:
# stellar
# dict_keys(['name', 175])
# dict_values(['stellar', 'aiml'])
# stellar
# {1: 'mangoes', 2: 'Apples', 3: 'Bananas'}
# {2: 'Apples', 3: 'Bananas'}

# %%
#5.Implement the methods of sets with examples.
#sets
set1={10,10,30,40}
set2={5,6.4,"Stelllar"}

list1=[10,20,70,50]
print(list1)
set3=set(list1)
print(set3)
#set methods
set1.add(55)
print(set1)

set2.update([5,9])
print(set2)

set1.discard(11)
print(set1)

list2=list(set1)
print(list2)

#set operation
c={10,20,30,44}
d={44,50,60,70}

#union
print(c|d)
print(c.union(d))
print(d.union(c))

#intersection
print(c&d)
print(c.intersection(d))
print(d.intersection(c))

#difference
print(c-d)
print(c.difference(d))
print(d-c)
print(d.difference(c))
# Out:
# [10, 20, 70, 50]
# {10, 20, 50, 70}
# {40, 10, 30, 55}
# {9, 'Stelllar', 5, 6.4}
# {40, 10, 30, 55}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-03b37f8e2ee3> in <module>
#      18 print(set1)
#      19
# ---> 20 list2=list(set1)
#      21 print(list2)
#      22
#
# TypeError: 'list' object is not callable

# %%
#6.Write a python program to convert decimal to binary,octal to hexadecimal with direct method. 

dec = 666
print("The decimal value of", dec, "is:")
print(bin(dec), "in binary.")
print(oct(dec), "in octal.")
print(hex(dec), "in hexadecimal.")
# Out:
# The decimal value of 666 is:
# 0b1010011010 in binary.
# 0o1232 in octal.
# 0x29a in hexadecimal.

# %%
#7.Implement arithmetic operators with examples.
#operators
#arithmetic operators
print("arithmetic operators")
a=30
b=5
print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# arithmetic operators
# 35
# 25
# 150
# 24300000
# 6.0
# 6
# 0

# %%
#8.Implement assignment operator with examples.
#assignment operator
a=30
b=6
c=a+b
print(c)
c-=a
print(c)
c+=a
print(c)
c-=b
print(c)
c+=b
print(c)
# Out:
# 36
# 6
# 36
# 30
# 36

# %%
#9.Implement comparision operator with examples.
#comparsion operateor
a=23
b=22
a>=b
print(a)
a==b
print(a)
a<=b
print(a)
a>=b
print(a)
a!=b
print(a)
# Out:
# 23
# 23
# 23
# 23
# 23

# %%
#10.Implement logical operators with examples.
#logical operators
a=False
b=True
print("a and b is",a and b)
print("a or b is",a or b)
print("a not b is", not b)
# Out:
# a and b is False
# a or b is True
# a not b is False

# %%
#11.Implement bitwise operators with examples.
#bitwise operators
a=11
b=19
print(a&b)#and
print(a|b)#or
print(-a)#not
print(a^b)#xor
print(a>>2)#right shift
print(a<<2)#left shift
# Out:
# 3
# 27
# -11
# 24
# 2
# 44

# %%
#12.Implement memebership operators with examples.
x="welcome"
print("w" in x)
y="python"
if("p" in y):
  print("present")
else:
  print("not present")
# Out:
# True
# present

# %%
#13.Implement identity operators with examples.
#identity operators
a=30
b=30
c="stellar"
d="Grad"
e=[10,20,30]
f=[10,20,30]
print(a is not b)
print(e is f)
print(c is d)
# Out:
# False
# False
# False

# %%
#14.Demonstrate negative indexeing for list and apply slicing.
list= [23,19,9,27,35,40,19,64,1]
print(list[::-1])
print(list[2:4])
print(list[2:7:5])
print(list[-3:-4:-2])
# Out:
# [1, 64, 19, 40, 35, 27, 9, 19, 23]
# [9, 27]
# [9]
# [19]

# %%
#15.Predict the output for the given code snippet and justify the result.
print('A series of character designated as one object known as a string'[::-1][5::2])
print('----------')
print('Welcome to python training program'[4:15][::-1])
# Out:
# sas wn cjoeos eagsdrtaacf ersA
# ----------
# htyp ot emo

# %%
#16.Write a python program to get a desired output.
#input string is:
P_phrase="was it a car or a cat I saw"
print("the output string is:",P_phrase[::-1].upper())
# Out:
# the output string is: WAS I TAC A RO RAC A TI SAW

# %%
#17
x=int(input())
y=x*x
a='Z'*x
print(a)
b='O'*y
print(b)
print(a+b)
# Out:
# 10
# ZZZZZZZZZZ
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# ZZZZZZZZZZOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
